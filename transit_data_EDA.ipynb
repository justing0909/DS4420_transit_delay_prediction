# %% [markdown]
# # DS4420 Transit Data EDA
# Exploring GTFS Schedule data for the MBTA. Loading data, observing features and preparing for analysis.

# %%
# imports
import pandas as pd

# %%
# load data
trips = pd.read_csv('MBTA_GTFS/trips.txt')
trips
# Out:
#                               route_id      service_id  \
# 0                                    1  WinterSaturday
# 1                                    1  WinterSaturday
# 2                                    1  WinterSaturday
# 3                                    1  WinterSaturday
# 4                                    1  WinterSaturday
# ...                                ...             ...
# 44004            Shuttle-StateSullivan       canonical
# 44005   Shuttle-SuffolkDownsWonderland       canonical
# 44006   Shuttle-SuffolkDownsWonderland       canonical
# 44007  Shuttle-TFGreenWickfordJunction       canonical
# 44008  Shuttle-TFGreenWickfordJunction       canonical
#
#                                 trip_id                trip_headsign  \
# 0                              66623853                      Harvard
# 1                              66623854                      Harvard
# 2                              66623856                      Harvard
# 3                              66623857                      Harvard
# 4                              66623858                      Harvard
# ...                                 ...                          ...
# 44004            StateSullivan-1-sample           Sullivan (Shuttle)
# 44005   SuffolkDownsWonderland-0-sample      Suffolk Downs (Shuttle)
# 44006   SuffolkDownsWonderland-1-sample         Wonderland (Shuttle)
# 44007  TFGreenWickfordJunction-0-sample  Wickford Junction (Shuttle)
# 44008  TFGreenWickfordJunction-1-sample   TF Green Airport (Shuttle)
#
#                    trip_short_name  direction_id block_id  \
# 0                              NaN             0   C01-12
# 1                              NaN             0    C01-2
# 2                              NaN             0    C01-4
# 3                              NaN             0   C01-10
# 4                              NaN             0    C01-2
# ...                            ...           ...      ...
# 44004           Sullivan (Shuttle)             1      NaN
# 44005      Suffolk Downs (Shuttle)             0      NaN
# 44006         Wonderland (Shuttle)             1      NaN
# 44007  Wickford Junction (Shuttle)             0      NaN
# 44008   TF Green Airport (Shuttle)             1      NaN
#
#                           shape_id  wheelchair_accessible  trip_route_type  \
# 0                           010138                      1              NaN
# 1                           010138                      1              NaN
# 2                           010138                      1              NaN
# 3                           010138                      1              NaN
# 4                           010138                      1              NaN
# ...                            ...                    ...              ...
# 44004            StateToSullivan-S                      1              3.0
# 44005   WonderlandToSuffolkDowns-S                      1              3.0
# 44006   SuffolkDownsToWonderland-S                      1              3.0
# 44007  TFGreenToWickfordJunction-S                      1              3.0
# 44008  WickfordJunctionToTFGreen-S                      1              3.0
#
#                           route_pattern_id  bikes_allowed
# 0                                    1-_-0              1
# 1                                    1-_-0              1
# 2                                    1-_-0              1
# 3                                    1-_-0              1
# 4                                    1-_-0              1
# ...                                    ...            ...
# 44004            Shuttle-StateSullivan-0-1              0
# 44005   Shuttle-SuffolkDownsWonderland-0-0              0
# 44006   Shuttle-SuffolkDownsWonderland-0-1              0
# 44007  Shuttle-TFGreenWickfordJunction-0-0              0
# 44008  Shuttle-TFGreenWickfordJunction-0-1              0
#
# [44009 rows x 12 columns]
